# %%
import requests
from bs4 import BeautifulSoup

for i in range(1,101): # 마지막 페이지 입력하기 101
    URL = 'https://finance.naver.com/research/debenture_list.nhn?keyword=&brokerCode=&searchType=writeDate&writeFromDate=2011-01-01&writeToDate=2021-12-31&x=0&y=0&page='+str(i)
    response = requests.get(URL)
    soup = BeautifulSoup(response.text, "html.parser")
    list_minutes = soup.select('div[id="contentarea_left"] div[class="box_type_m"] tr')
    for minutes in list_minutes:
        try:
            title=minutes.select('a')[0].text
            sub_link = minutes.select('a')[1].attrs['href']
            if str(sub_link).endswith('.pdf'):
                print(title)
                print(sub_link)
                file_res = requests.get(sub_link)
                with open('{}.pdf'.format(title), 'wb') as f:
                    f.write(file_res.content)
            else:
                pass
            
#           print(minutes)


        except:
            pass
        
        # pdf_check = minutes.select('a')[2].attrs['title']
        # title = minutes.find('span').text
        
#         file_res = requests.get(sub_link)
#         with open('{}.pdf'.format(title), 'wb') as f:
#             f.write(file_res.content)
# Out:
# 원점회귀(原點回歸)
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1609287430905.pdf
# 포트폴리오 다변화로 가는 여정
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1608683256891.pdf
# 2021년 전망 업데이트
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1608682463605.pdf
# 일드 픽업 이제는 장기물이 답이다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1608250720892.pdf
# 10년 발행 감소, 초장기 공급부담 완화
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1608250019740.pdf
# 연말이 뜨거운 이유
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1608078550815.pdf
# 여전채, 강한 수요 강한 발행
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1607646962600.pdf
# 금리 레벨이 부담스럽다면 TIPS를 대안으로
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1607558673496.pdf
# 뜨거운 겨울
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1607472978258.pdf
# 통화정책에 대한 믿음이 변할까
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1607299925739.pdf
# 12월 일드 픽업은 여전채로
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1607041124503.pdf
# ETF 혹은 개별국가 선택 통한 전략 재편
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606953797719.pdf
# 연말효과가 없으면 연초효과도 제한적일 것
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606867307259.pdf
# 3 10년 스프레드, 언제 정점을 기록할까
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606867273949.pdf
# 잇따른 국영기업의 채무불이행, 중국 크레딧 리스크 ..
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606695774874.pdf
# 반복되는 리스크와 학습효과
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606695646513.pdf
# 격하게 진행되는 크레딧 일드 픽업
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606436868430.pdf
# 올해와 내년 경제성장률 상향
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606436145276.pdf
# 예년과 다른 연말
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606263559471.pdf
# 미국 금리, 눌러도 눌리지 않는다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1606263529143.pdf
# 11월의 크레딧 초강세, 놀랍지만 이상하지 않다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605832081882.pdf
# 물가연동국채, 천천히 뚜벅뚜벅
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605745187602.pdf
# BS군과 IS양이 만나 CF를 낳다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605659073167.pdf
# 브라질 지방선거 결과 코멘트
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605658912401.pdf
# 또 다시 갈림길에 서다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605571686731.pdf
# 백신개발이 통화정책 정상화에 미칠 영향
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605139305908.pdf
# 지금은 방어가 최선의 전략이다
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1605054099382.pdf
# MBS 공급감소와 발행스프레드 강보합 전망
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1604968489686.pdf
# 3 개의 허들 (Hurdle)
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1604881628350.pdf
# 당분간 미국채 박스권. 채권전략 키워드는 일드 픽업
# https://ssl.pstatic.net/imgstock/upload/research/debenture/1604624336426.pdf
